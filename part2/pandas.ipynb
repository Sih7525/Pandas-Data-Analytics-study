# %%
#시리즈와 데이터프레임 두가지가 기본이다

import numpy as np
import pandas as pd

# %%
dic = {'city': ['서울', '부산', '대전', '대구', '광주'],
          'year': [2017, 2017, 2018, 2018, 2018],
          'temp': [18, 20, 19, 21, 20]}
data = pd.DataFrame(dic) ; data
# Out:
#   city  year  temp
# 0   서울  2017    18
# 1   부산  2017    20
# 2   대전  2018    19
# 3   대구  2018    21
# 4   광주  2018    20

# %%
data[['year', 'city', 'temp' ]]
# Out:
#    year city  temp
# 0  2017   서울    18
# 1  2017   부산    20
# 2  2018   대전    19
# 3  2018   대구    21
# 4  2018   광주    20

# %%
#index는 순서 0>a
data.index = ['a', 'b', 'c', 'd', 'e'] ;data
# Out:
#   city  year  temp
# a   서울  2017    18
# b   부산  2017    20
# c   대전  2018    19
# d   대구  2018    21
# e   광주  2018    20

# %%
data.columns = ['도시', '연도', '날씨'] ;data
# Out:
#    도시    연도  날씨
# a  서울  2017  18
# b  부산  2017  20
# c  대전  2018  19
# d  대구  2018  21
# e  광주  2018  20

# %%
data.set_index(['도시'])
# Out:
#       연도  날씨
# 도시
# 서울  2017  18
# 부산  2017  20
# 대전  2018  19
# 대구  2018  21
# 광주  2018  20

# %%
data['연도']
# Out:
# a    2017
# b    2017
# c    2018
# d    2018
# e    2018
# Name: 연도, dtype: int64

# %%
data.연도
# Out:
# a    2017
# b    2017
# c    2018
# d    2018
# e    2018
# Name: 연도, dtype: int64

# %%
data.loc['a']
# Out:
# 도시      서울
# 연도    2017
# 날씨      18
# Name: a, dtype: object

# %%
data.set_index(['도시'], inplace=True) ;data
# Out:
#       연도  날씨
# 도시
# 서울  2017  18
# 부산  2017  20
# 대전  2018  19
# 대구  2018  21
# 광주  2018  20

# %%
data
# Out:
#       연도  날씨
# 도시
# 서울  2017  18
# 부산  2017  20
# 대전  2018  19
# 대구  2018  21
# 광주  2018  20

# %%
data.loc[['서울', '부산']]
# Out:
#       연도  날씨
# 도시
# 서울  2017  18
# 부산  2017  20

# %%
data.iloc[1:3]
# Out:
#       연도  날씨
# 도시
# 부산  2017  20
# 대전  2018  19

# %%
cars = [50,40,30,20,10]
data['car'] = cars 
data
# Out:
#       연도  날씨  car
# 도시
# 서울  2017  18   50
# 부산  2017  20   40
# 대전  2018  19   30
# 대구  2018  21   20
# 광주  2018  20   10

# %%
data['high']= data.car >=30 ;data
# Out:
#       연도  날씨  car   high
# 도시
# 서울  2017  18   50   True
# 부산  2017  20   40   True
# 대전  2018  19   30   True
# 대구  2018  21   20  False
# 광주  2018  20   10  False

# %%
data.drop('car', 1)
# Out:
#       연도  날씨   high
# 도시
# 서울  2017  18   True
# 부산  2017  20   True
# 대전  2018  19   True
# 대구  2018  21  False
# 광주  2018  20  False

# %%
data.drop('서울')
# Out:
#       연도  날씨  car   high
# 도시
# 부산  2017  20   40   True
# 대전  2018  19   30   True
# 대구  2018  21   20  False
# 광주  2018  20   10  False

# %%
#람다함수
f = lambda x: x.max() - x.min()

# %%
df = pd.DataFrame(np.arange(12).reshape(4,3),
                    columns=['A', 'B', 'C'], index=['a', 'b', 'c', 'd'])
df
# Out:
#    A   B   C
# a  0   1   2
# b  3   4   5
# c  6   7   8
# d  9  10  11

# %%
df.apply(f)
# Out:
# A    9
# B    9
# C    9
# dtype: int64

# %%
df.apply(f, axis=1)
# Out:
# a    2
# b    2
# c    2
# d    2
# dtype: int64

# %%
data
# Out:
#       연도  날씨  car   high
# 도시
# 서울  2017  18   50   True
# 부산  2017  20   40   True
# 대전  2018  19   30   True
# 대구  2018  21   20  False
# 광주  2018  20   10  False

# %%
data.rename(columns={'car':'차', 'high':'높이'}, inplace=True)
data
# Out:
#       연도  날씨   차     높이
# 도시
# 서울  2017  18  50   True
# 부산  2017  20  40   True
# 대전  2018  19  30   True
# 대구  2018  21  20  False
# 광주  2018  20  10  False

# %%
exam_data = {'수학' : [90,80,70],'영어': [98,89,88],'체육':[80,100,95]}
exam_data
# Out:
# {'수학': [90, 80, 70], '영어': [98, 89, 88], '체육': [80, 100, 95]}

# %%
df = pd.DataFrame(exam_data, index=['짱구','맹구','철수'])
df
# Out:
#     수학  영어   체육
# 짱구  90  98   80
# 맹구  80  89  100
# 철수  70  88   95

# %%
df2 = df[:]

# %%
df2
# Out:
#     수학  영어   체육
# 짱구  90  98   80
# 맹구  80  89  100
# 철수  70  88   95

# %%
df2.drop(['짱구','철수'], axis=0, inplace=True)
df2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#     수학  영어   체육
# 맹구  80  89  100

# %%
df.iloc[::2]
# Out:
#     수학  영어  체육
# 짱구  90  98  80
# 철수  70  88  95

# %%
# 행 추가
df.loc['훈이'] = [86,90,85]

# %%
df
# Out:
#     수학  영어   체육
# 짱구  90  98   80
# 맹구  80  89  100
# 철수  70  88   95
# 훈이  86  90   85

# %%
# 열 추가
df['미술'] = [50,49,23,44]
df
# Out:
#     수학  영어   체육  미술
# 짱구  90  98   80  50
# 맹구  80  89  100  49
# 철수  70  88   95  23
# 훈이  86  90   85  44

# %%
df.loc['짱구','체육'] = 100
df
# Out:
#     수학  영어   체육  미술
# 짱구  90  98  100  50
# 맹구  80  89  100  49
# 철수  70  88   95  23
# 훈이  86  90   85  44

# %%
df.transpose()
# Out:
#      짱구   맹구  철수  훈이
# 수학   90   80  70  86
# 영어   98   89  88  90
# 체육  100  100  95  85
# 미술   50   49  23  44

# %%
df
# Out:
#     수학  영어   체육  미술
# 짱구  90  98  100  50
# 맹구  80  89  100  49
# 철수  70  88   95  23
# 훈이  86  90   85  44

# %%
df
# Out:
#      짱구   맹구  철수  훈이
# 수학   90   80  70  86
# 영어   98   89  88  90
# 체육  100  100  95  85
# 미술   50   49  23  44

# %%
ndf = df.reset_index()
ndf
# Out:
#   index  수학  영어   체육  미술
# 0    짱구  90  98  100  50
# 1    맹구  80  89  100  49
# 2    철수  70  88   95  23
# 3    훈이  86  90   85  44

# %%
df.sort_values(by='수학',ascending=False)
# Out:
#     수학  영어   체육  미술
# 짱구  90  98  100  50
# 훈이  86  90   85  44
# 맹구  80  89  100  49
# 철수  70  88   95  23

# %%
df
# Out:
#     수학  영어   체육  미술
# 짱구  90  98  100  50
# 맹구  80  89  100  49
# 철수  70  88   95  23
# 훈이  86  90   85  44

# %%
data= {'name' : ['Jerry','Riah','paul'],
       'algol' : ['A','A+','C'],
      'basic' : ['C','B+','C+'],
      'python': ['B+','A','B'],
      }

df = pd.DataFrame(data)
df.set_index('name',inplace=True)
print(df)

#to_csv()메소드를 사용하여 csv파일로 내보내기. 파일명은 df_sample.csv로 저장
df.to_csv('df_sample.csv')
# Out:
#       algol basic python
# name
# Jerry     A     C     B+
# Riah     A+    B+      A
# paul      C    C+      B
